# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
import requests
requests.get("http://localhost:11434").content
ollama_url = "http://localhost:11434/v1"
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

OllamaModels=["deepseek-r1:1.5b",
"llama3.2:latest",
"codeguru:latest",
"codellama:latest",
"qwen3.5:0.8b",
"mistral:latest",
"llama2:latest",
"gemma:2b"
]

# %%
message="""
give me a tool call format for the following tool:
Tool Name: get_ticket_price

def get_ticket_price(destination_city):
    print(f"Tool called for city {destination_city}")
    price = ticket_prices.get(destination_city.lower(), "Unknown ticket price")
    return f"The price of a ticket to {destination_city} is {price}"

like this 
price_function = {
    "name": "tool name",
    "description": "tool Description",
    "parameters": {
        "type": "object",
        "properties": {
            "input name": {
                "type": type of input,
                "description": "description of input",
            },
        },
        "required": which inputs are required,
        "additionalProperties": False
    }
}

"""


tool_Call_Format=[{"role": "user", "content": message}]

# %%
response = ollama.chat.completions.create(model=OllamaModels[3], messages=tool_Call_Format)
# response.choices[0].message.content

# %%
Markdown(response.choices[0].message.content)
# Out:
# ```
# price_function = {
#     "name": "get_ticket_price",
#     "description": "This function will return the price of a ticket to a destination city.",
#     "parameters": {
#         "type": "object",
#         "properties": {
#             "destination_city": {
#                 "type": "string",
#                 "description": "The name of the destination city for which you want to know the ticket price.",
#                 "required": True,
#                 "example": "New York"
#             }
#         },
#         "required": ["destination_city"],
#         "additionalProperties": False
#     }
# }
# ```
