# %%
import ml_utils as mlutils

# %%
[x for x in dir(mlutils) if not x.startswith("_")]
# Out:
# ['data_cleaning', 'feature_engineering', 'outliers', 'scalar']

# %%
[x for x in dir(mlutils.data_cleaning) if not x.startswith("_")]
# Out:
# ['KNNImputer',
#  'SimpleImputer',
#  'categorical_imputer',
#  'clean_column_names',
#  'drop_columns',
#  'drop_null_rows',
#  'find_duplicates',
#  'get_column_types',
#  'missing_values',
#  'numerical_imputer',
#  'pickle',
#  'remove_constant_columns',
#  'remove_duplicates']

# %%
[x for x in dir(mlutils.feature_engineering) if not x.startswith("_")]
# Out:
# ['LabelEncoder', 'label_encode', 'pickle', 'target_label_encode']

# %%
[x for x in dir(mlutils.outliers) if not x.startswith("_")]
# Out:
# ['detect_outliers', 'os', 'pd', 'pickle', 'replace_outliers']

# %%
[x for x in dir(mlutils.scalar) if not x.startswith("_")]
# Out:
# ['StandardScaler', 'scale_features']
