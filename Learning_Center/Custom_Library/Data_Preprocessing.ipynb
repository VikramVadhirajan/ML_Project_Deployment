# %%
import ml_utils as mlu
from ml_utils import *
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
[x for x in dir(mlu) if not x.startswith("_")]
# Out:
# ['KNNImputer',
#  'LabelEncoder',
#  'SimpleImputer',
#  'StandardScaler',
#  'categorical_imputer',
#  'clean_column_names',
#  'data_cleaning',
#  'detect_outliers',
#  'drop_columns',
#  'drop_null_rows',
#  'feature_engineering',
#  'find_duplicates',
#  'get_column_types',
#  'label_encode',
#  'missing_values',
#  'numerical_imputer',
#  'os',
#  'outliers',
#  'pd',
#  'pickle',
#  'remove_constant_columns',
#  'remove_duplicates',
#  'replace_outliers',
#  'scalar',
#  'scale_features',
#  'target_label_encode']

# %%
[x for x in dir(mlu.data_cleaning) if not x.startswith("_")]
# Out:
# ['KNNImputer',
#  'SimpleImputer',
#  'categorical_imputer',
#  'clean_column_names',
#  'drop_columns',
#  'drop_null_rows',
#  'find_duplicates',
#  'get_column_types',
#  'missing_values',
#  'numerical_imputer',
#  'pickle',
#  'remove_constant_columns',
#  'remove_duplicates']

# %%
[x for x in dir(mlu.feature_engineering) if not x.startswith("_")]
# Out:
# ['LabelEncoder', 'label_encode', 'pickle', 'target_label_encode']

# %%
[x for x in dir(mlu.outliers) if not x.startswith("_")]
# Out:
# ['detect_outliers', 'os', 'pd', 'pickle', 'replace_outliers']

# %%
[x for x in dir(mlu.scalar) if not x.startswith("_")]
# Out:
# ['StandardScaler', 'scale_features']
